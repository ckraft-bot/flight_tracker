# %%
import pandas as pd

data = [
    {
        'Direction': 'Arrival',
        'Airline': 'United Airlines',
        'Flight': 'UA5870',
        'From': 'ORD',
        'To': 'CHA',
        'Latitude': 34.9088,
        'Longitude': -85.2491,
        'Altitude (ft)': 731.52,
        'Speed (km/h)': 303.728,
        'Scheduled Departure': '2025-07-02 10:35',
        'Estimated Departure': '2025-07-02 10:35',
        'Actual Departure': '',
        'Scheduled Arrival': '2025-07-02 13:23',
        'Estimated Arrival': '',
        'Actual Arrival': '',
        'Flight Status': 'active'
    },
    {
        'Direction': 'Arrival',
        'Airline': 'Allegiant Air',
        'Flight': 'G41221',
        'From': 'SFB',
        'To': 'CHA',
        'Latitude': 34.6959,
        'Longitude': -85.0884,
        'Altitude (ft)': 2133.60,
        'Speed (km/h)': 505.596,
        'Scheduled Departure': '2025-07-02 13:06',
        'Estimated Departure': '2025-07-02 13:06',
        'Actual Departure': '',
        'Scheduled Arrival': '2025-07-02 14:41',
        'Estimated Arrival': '',
        'Actual Arrival': '',
        'Flight Status': 'scheduled'
    },
    {
        'Direction': 'Departure',
        'Airline': 'American Airlines',
        'Flight': 'AA9781',
        'From': 'CHA',
        'To': 'DFW',
        'Latitude': 35.0911,
        'Longitude': -86.6049,
        'Altitude (ft)': 7810.50,
        'Speed (km/h)': 851.920,
        'Scheduled Departure': '2025-07-03 11:15',
        'Estimated Departure': '2025-07-03 11:15',
        'Actual Departure': '',
        'Scheduled Arrival': '2025-07-03 12:24',
        'Estimated Arrival': '',
        'Actual Arrival': '',
        'Flight Status': 'scheduled'
    }
]

df = pd.DataFrame(data)
df
df.to_csv("flights.csv", index=False)
# # Optional: display the DataFrame
# print(df.to_string(index=False))
